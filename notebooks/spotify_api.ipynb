# %% [markdown]
# ## Spotify API notebook
# This Notebook is used to extract songs and artits information using Python APIs

# %%
# libraries import

from dotenv import load_dotenv
import os
import base64
from requests import post,get
import json 
import pandas as pd
import numpy as np

# %% [markdown]
# Here we load the keys necessary to access the Spotify API

# %%
load_dotenv()
client_id=os.getenv('CLIENT_ID')
client_service=os.getenv('CLIENT_SECRET')

# %% [markdown]
# Functions used to access the Spotify API endpoint

# %%
def get_token():
    auth_string= client_id+':'+client_service
    auth_bytes= auth_string.encode('utf-8')
    auth_base64= str(base64.b64encode(auth_bytes),'utf-8')

    url='https://accounts.spotify.com/api/token'
    headers={
        'Authorization': 'Basic '+auth_base64,
        'Content-Type': 'application/x-www-form-urlencoded'
    }
    data={'grant_type': 'client_credentials'}
    result= post(url, headers=headers, data=data)
    json_result=json.loads(result.content)
    token=json_result['access_token']
    return token

def get_auth_header(token):
    return {'Authorization': 'Bearer '+token}

# %% [markdown]
# This function is used to retrieve information of the given Spotify artist

# %%
def search_for_artist(token, artist_name):
    url= 'https://api.spotify.com/v1/search'
    headers= get_auth_header(token)
    query= f'?q={artist_name}&type=artist&limit=1'

    query_url= url+query
    result=get(query_url,headers=headers)
    if result.status_code == 200:
         # Request was successful, proceed with parsing the response
        json_result=json.loads(result.content)['artists']['items']
        if len(json_result)==0:
            print('No artists')
            return None
        return json_result[0]
    else:
        # Handle error cases
        print(f"Error: {result.status_code}")
        return None

# %% [markdown]
# This function aims to extract informations of the specified Spotify song

# %%
def search_for_song(token,song_id):
    url= f'https://api.spotify.com/v1/tracks/?ids={song_id}'
    headers= get_auth_header(token)
    

    result=get(url,headers=headers)
    if result.status_code == 200:
        # Request was successful, proceed with parsing the response
        json_result = json.loads(result.content)['tracks']
        return json_result
    else:
        # Handle error cases
        print(f"Error: {result.status_code}")
        return None

# %% [markdown]
# Data pre-processing of the dataset

# %%
token=get_token()
df = pd.read_csv('/Users/gianluca/Downloads/Spotify_Youtube-1.csv',usecols=['Artist','Uri'])
data=df['Artist'].drop_duplicates()
data=pd.DataFrame(data,columns =['Artist'])
data['Followers']=0
data['Genres']=""
data['Popularity']=0

song_uris=df[['Uri']]
song_ids= song_uris['Uri'].apply(lambda x: x.split(':')[-1])
song_ids=pd.DataFrame(song_ids,columns =['Uri'])

album=pd.DataFrame(columns=['Id','Album','Total_tracks','Release_date','Available_market'])

# %% [markdown]
# Here we perform the gathering information of the songs present in the dataset.
#
# Since the API has a time limit requests, we subdivide the songs into batches of ~40 songs, in order to perform less request to the Spotify endpoint.

# %%
# 500 is the number of batches
df_batches = np.array_split(song_ids, 500)
request=""
index=0
for i, batch in enumerate(df_batches):
    print(f"start processing batch {i+1} \n size:{len(batch)}")
    for j,album_info in batch.iterrows():
        request+=album_info[0]+','
    request=request[:-1]
    res=search_for_song(token,request)
    res=pd.DataFrame(res)
    for info in res.iterrows():
        info=info[1]
        album.at[index,'Id']=info[0]['uri']
        album.at[index,'Album']=info[0]['name'] #track name
        album.at[index,'Total_tracks']=info[0]['total_tracks']
        album.at[index,'Release_date']=info[0]['release_date']
        album.at[index,"Available_market"]=info['available_markets']
        index+=1

    print(f"end processing batch {i+1} \n")
    request=""
# Out:
# start processing batch 1
#  size:42
# end processing batch 1
#
# start processing batch 2
#  size:42
# end processing batch 2
#
# start processing batch 3
#  size:42
# end processing batch 3
#
# start processing batch 4
#  size:42
# end processing batch 4
#
# start processing batch 5
#  size:42
# end processing batch 5
#
# start processing batch 6
#  size:42
# end processing batch 6
#
# start processing batch 7
#  size:42
# end processing batch 7
#
# start processing batch 8
#  size:42
# end processing batch 8
#
# start processing batch 9
#  size:42
# end processing batch 9
#
# start processing batch 10
#  size:42
# end processing batch 10
#
# start processing batch 11
#  size:42
# end processing batch 11
#
# start processing batch 12
#  size:42
# end processing batch 12
#
# start processing batch 13
#  size:42
# end processing batch 13
#
# start processing batch 14
#  size:42
# end processing batch 14
#
# start processing batch 15
#  size:42
# end processing batch 15
#
# start processing batch 16
#  size:42
# end processing batch 16
#
# start processing batch 17
#  size:42
# end processing batch 17
#
# start processing batch 18
#  size:42
# end processing batch 18
#
# start processing batch 19
#  size:42
# end processing batch 19
#
# start processing batch 20
#  size:42
# end processing batch 20
#
# start processing batch 21
#  size:42
# end processing batch 21
#
# start processing batch 22
#  size:42
# end processing batch 22
#
# start processing batch 23
#  size:42
# end processing batch 23
#
# start processing batch 24
#  size:42
# end processing batch 24
#
# start processing batch 25
#  size:42
# end processing batch 25
#
# start processing batch 26
#  size:42
# end processing batch 26
#
# start processing batch 27
#  size:42
# end processing batch 27
#
# start processing batch 28
#  size:42
# end processing batch 28
#
# start processing batch 29
#  size:42
# end processing batch 29
#
# start processing batch 30
#  size:42
# end processing batch 30
#
# start processing batch 31
#  size:42
# end processing batch 31
#
# start processing batch 32
#  size:42
# end processing batch 32
#
# start processing batch 33
#  size:42
# end processing batch 33
#
# start processing batch 34
#  size:42
# end processing batch 34
#
# start processing batch 35
#  size:42
# end processing batch 35
#
# start processing batch 36
#  size:42
# end processing batch 36
#
# start processing batch 37
#  size:42
# end processing batch 37
#
# start processing batch 38
#  size:42
# end processing batch 38
#
# start processing batch 39
#  size:42
# end processing batch 39
#
# start processing batch 40
#  size:42
# end processing batch 40
#
# start processing batch 41
#  size:42
# end processing batch 41
#
# start processing batch 42
#  size:42
# end processing batch 42
#
# start processing batch 43
#  size:42
# end processing batch 43
#
# start processing batch 44
#  size:42
# end processing batch 44
#
# start processing batch 45
#  size:42
# end processing batch 45
#
# start processing batch 46
#  size:42
# end processing batch 46
#
# start processing batch 47
#  size:42
# end processing batch 47
#
# start processing batch 48
#  size:42
# end processing batch 48
#
# start processing batch 49
#  size:42
# end processing batch 49
#
# start processing batch 50
#  size:42
# end processing batch 50
#
# start processing batch 51
#  size:42
# end processing batch 51
#
# start processing batch 52
#  size:42
# end processing batch 52
#
# start processing batch 53
#  size:42
# end processing batch 53
#
# start processing batch 54
#  size:42
# end processing batch 54
#
# start processing batch 55
#  size:42
# end processing batch 55
#
# start processing batch 56
#  size:42
# end processing batch 56
#
# start processing batch 57
#  size:42
# end processing batch 57
#
# start processing batch 58
#  size:42
# end processing batch 58
#
# start processing batch 59
#  size:42
# end processing batch 59
#
# start processing batch 60
#  size:42
# end processing batch 60
#
# start processing batch 61
#  size:42
# end processing batch 61
#
# start processing batch 62
#  size:42
# end processing batch 62
#
# start processing batch 63
#  size:42
# end processing batch 63
#
# start processing batch 64
#  size:42
# end processing batch 64
#
# start processing batch 65
#  size:42
# end processing batch 65
#
# start processing batch 66
#  size:42
# end processing batch 66
#
# start processing batch 67
#  size:42
# end processing batch 67
#
# start processing batch 68
#  size:42
# end processing batch 68
#
# start processing batch 69
#  size:42
# end processing batch 69
#
# start processing batch 70
#  size:42
# end processing batch 70
#
# start processing batch 71
#  size:42
# end processing batch 71
#
# start processing batch 72
#  size:42
# end processing batch 72
#
# start processing batch 73
#  size:42
# end processing batch 73
#
# start processing batch 74
#  size:42
# end processing batch 74
#
# start processing batch 75
#  size:42
# end processing batch 75
#
# start processing batch 76
#  size:42
# end processing batch 76
#
# start processing batch 77
#  size:42
# end processing batch 77
#
# start processing batch 78
#  size:42
# end processing batch 78
#
# start processing batch 79
#  size:42
# end processing batch 79
#
# start processing batch 80
#  size:42
# end processing batch 80
#
# start processing batch 81
#  size:42
# end processing batch 81
#
# start processing batch 82
#  size:42
# end processing batch 82
#
# start processing batch 83
#  size:42
# end processing batch 83
#
# start processing batch 84
#  size:42
# end processing batch 84
#
# start processing batch 85
#  size:42
# end processing batch 85
#
# start processing batch 86
#  size:42
# end processing batch 86
#
# start processing batch 87
#  size:42
# end processing batch 87
#
# start processing batch 88
#  size:42
# end processing batch 88
#
# start processing batch 89
#  size:42
# end processing batch 89
#
# start processing batch 90
#  size:42
# end processing batch 90
#
# start processing batch 91
#  size:42
# end processing batch 91
#
# start processing batch 92
#  size:42
# end processing batch 92
#
# start processing batch 93
#  size:42
# end processing batch 93
#
# start processing batch 94
#  size:42
# end processing batch 94
#
# start processing batch 95
#  size:42
# end processing batch 95
#
# start processing batch 96
#  size:42
# end processing batch 96
#
# start processing batch 97
#  size:42
# end processing batch 97
#
# start processing batch 98
#  size:42
# end processing batch 98
#
# start processing batch 99
#  size:42
# end processing batch 99
#
# start processing batch 100
#  size:42
# end processing batch 100
#
# start processing batch 101
#  size:42
# end processing batch 101
#
# start processing batch 102
#  size:42
# end processing batch 102
#
# start processing batch 103
#  size:42
# end processing batch 103
#
# start processing batch 104
#  size:42
# end processing batch 104
#
# start processing batch 105
#  size:42
# end processing batch 105
#
# start processing batch 106
#  size:42
# end processing batch 106
#
# start processing batch 107
#  size:42
# end processing batch 107
#
# start processing batch 108
#  size:42
# end processing batch 108
#
# start processing batch 109
#  size:42
# end processing batch 109
#
# start processing batch 110
#  size:42
# end processing batch 110
#
# start processing batch 111
#  size:42
# end processing batch 111
#
# start processing batch 112
#  size:42
# end processing batch 112
#
# start processing batch 113
#  size:42
# end processing batch 113
#
# start processing batch 114
#  size:42
# end processing batch 114
#
# start processing batch 115
#  size:42
# end processing batch 115
#
# start processing batch 116
#  size:42
# end processing batch 116
#
# start processing batch 117
#  size:42
# end processing batch 117
#
# start processing batch 118
#  size:42
# end processing batch 118
#
# start processing batch 119
#  size:42
# end processing batch 119
#
# start processing batch 120
#  size:42
# end processing batch 120
#
# start processing batch 121
#  size:42
# end processing batch 121
#
# start processing batch 122
#  size:42
# end processing batch 122
#
# start processing batch 123
#  size:42
# end processing batch 123
#
# start processing batch 124
#  size:42
# end processing batch 124
#
# start processing batch 125
#  size:42
# end processing batch 125
#
# start processing batch 126
#  size:42
# end processing batch 126
#
# start processing batch 127
#  size:42
# end processing batch 127
#
# start processing batch 128
#  size:42
# end processing batch 128
#
# start processing batch 129
#  size:42
# end processing batch 129
#
# start processing batch 130
#  size:42
# end processing batch 130
#
# start processing batch 131
#  size:42
# end processing batch 131
#
# start processing batch 132
#  size:42
# end processing batch 132
#
# start processing batch 133
#  size:42
# end processing batch 133
#
# start processing batch 134
#  size:42
# end processing batch 134
#
# start processing batch 135
#  size:42
# end processing batch 135
#
# start processing batch 136
#  size:42
# end processing batch 136
#
# start processing batch 137
#  size:42
# end processing batch 137
#
# start processing batch 138
#  size:42
# end processing batch 138
#
# start processing batch 139
#  size:42
# end processing batch 139
#
# start processing batch 140
#  size:42
# end processing batch 140
#
# start processing batch 141
#  size:42
# end processing batch 141
#
# start processing batch 142
#  size:42
# end processing batch 142
#
# start processing batch 143
#  size:42
# end processing batch 143
#
# start processing batch 144
#  size:42
# end processing batch 144
#
# start processing batch 145
#  size:42
# end processing batch 145
#
# start processing batch 146
#  size:42
# end processing batch 146
#
# start processing batch 147
#  size:42
# end processing batch 147
#
# start processing batch 148
#  size:42
# end processing batch 148
#
# start processing batch 149
#  size:42
# end processing batch 149
#
# start processing batch 150
#  size:42
# end processing batch 150
#
# start processing batch 151
#  size:42
# end processing batch 151
#
# start processing batch 152
#  size:42
# end processing batch 152
#
# start processing batch 153
#  size:42
# end processing batch 153
#
# start processing batch 154
#  size:42
# end processing batch 154
#
# start processing batch 155
#  size:42
# end processing batch 155
#
# start processing batch 156
#  size:42
# end processing batch 156
#
# start processing batch 157
#  size:42
# end processing batch 157
#
# start processing batch 158
#  size:42
# end processing batch 158
#
# start processing batch 159
#  size:42
# end processing batch 159
#
# start processing batch 160
#  size:42
# end processing batch 160
#
# start processing batch 161
#  size:42
# end processing batch 161
#
# start processing batch 162
#  size:42
# end processing batch 162
#
# start processing batch 163
#  size:42
# end processing batch 163
#
# start processing batch 164
#  size:42
# end processing batch 164
#
# start processing batch 165
#  size:42
# end processing batch 165
#
# start processing batch 166
#  size:42
# end processing batch 166
#
# start processing batch 167
#  size:42
# end processing batch 167
#
# start processing batch 168
#  size:42
# end processing batch 168
#
# start processing batch 169
#  size:42
# end processing batch 169
#
# start processing batch 170
#  size:42
# end processing batch 170
#
# start processing batch 171
#  size:42
# end processing batch 171
#
# start processing batch 172
#  size:42
# end processing batch 172
#
# start processing batch 173
#  size:42
# end processing batch 173
#
# start processing batch 174
#  size:42
# end processing batch 174
#
# start processing batch 175
#  size:42
# end processing batch 175
#
# start processing batch 176
#  size:42
# end processing batch 176
#
# start processing batch 177
#  size:42
# end processing batch 177
#
# start processing batch 178
#  size:42
# end processing batch 178
#
# start processing batch 179
#  size:42
# end processing batch 179
#
# start processing batch 180
#  size:42
# end processing batch 180
#
# start processing batch 181
#  size:42
# end processing batch 181
#
# start processing batch 182
#  size:42
# end processing batch 182
#
# start processing batch 183
#  size:42
# end processing batch 183
#
# start processing batch 184
#  size:42
# end processing batch 184
#
# start processing batch 185
#  size:42
# end processing batch 185
#
# start processing batch 186
#  size:42
# end processing batch 186
#
# start processing batch 187
#  size:42
# end processing batch 187
#
# start processing batch 188
#  size:42
# end processing batch 188
#
# start processing batch 189
#  size:42
# end processing batch 189
#
# start processing batch 190
#  size:42
# end processing batch 190
#
# start processing batch 191
#  size:42
# end processing batch 191
#
# start processing batch 192
#  size:42
# end processing batch 192
#
# start processing batch 193
#  size:42
# end processing batch 193
#
# start processing batch 194
#  size:42
# end processing batch 194
#
# start processing batch 195
#  size:42
# end processing batch 195
#
# start processing batch 196
#  size:42
# end processing batch 196
#
# start processing batch 197
#  size:42
# end processing batch 197
#
# start processing batch 198
#  size:42
# end processing batch 198
#
# start processing batch 199
#  size:42
# end processing batch 199
#
# start processing batch 200
#  size:42
# end processing batch 200
#
# start processing batch 201
#  size:42
# end processing batch 201
#
# start processing batch 202
#  size:42
# end processing batch 202
#
# start processing batch 203
#  size:42
# end processing batch 203
#
# start processing batch 204
#  size:42
# end processing batch 204
#
# start processing batch 205
#  size:42
# end processing batch 205
#
# start processing batch 206
#  size:42
# end processing batch 206
#
# start processing batch 207
#  size:42
# end processing batch 207
#
# start processing batch 208
#  size:42
# end processing batch 208
#
# start processing batch 209
#  size:42
# end processing batch 209
#
# start processing batch 210
#  size:42
# end processing batch 210
#
# start processing batch 211
#  size:42
# end processing batch 211
#
# start processing batch 212
#  size:42
# end processing batch 212
#
# start processing batch 213
#  size:42
# end processing batch 213
#
# start processing batch 214
#  size:42
# end processing batch 214
#
# start processing batch 215
#  size:42
# end processing batch 215
#
# start processing batch 216
#  size:42
# end processing batch 216
#
# start processing batch 217
#  size:42
# end processing batch 217
#
# start processing batch 218
#  size:42
# end processing batch 218
#
# start processing batch 219
#  size:41
# end processing batch 219
#
# start processing batch 220
#  size:41
# end processing batch 220
#
# start processing batch 221
#  size:41
# end processing batch 221
#
# start processing batch 222
#  size:41
# end processing batch 222
#
# start processing batch 223
#  size:41
# end processing batch 223
#
# start processing batch 224
#  size:41
# end processing batch 224
#
# start processing batch 225
#  size:41
# end processing batch 225
#
# start processing batch 226
#  size:41
# end processing batch 226
#
# start processing batch 227
#  size:41
# end processing batch 227
#
# start processing batch 228
#  size:41
# end processing batch 228
#
# start processing batch 229
#  size:41
# end processing batch 229
#
# start processing batch 230
#  size:41
# end processing batch 230
#
# start processing batch 231
#  size:41
# end processing batch 231
#
# start processing batch 232
#  size:41
# end processing batch 232
#
# start processing batch 233
#  size:41
# end processing batch 233
#
# start processing batch 234
#  size:41
# end processing batch 234
#
# start processing batch 235
#  size:41
# end processing batch 235
#
# start processing batch 236
#  size:41
# end processing batch 236
#
# start processing batch 237
#  size:41
# end processing batch 237
#
# start processing batch 238
#  size:41
# end processing batch 238
#
# start processing batch 239
#  size:41
# end processing batch 239
#
# start processing batch 240
#  size:41
# end processing batch 240
#
# start processing batch 241
#  size:41
# end processing batch 241
#
# start processing batch 242
#  size:41
# end processing batch 242
#
# start processing batch 243
#  size:41
# end processing batch 243
#
# start processing batch 244
#  size:41
# end processing batch 244
#
# start processing batch 245
#  size:41
# end processing batch 245
#
# start processing batch 246
#  size:41
# end processing batch 246
#
# start processing batch 247
#  size:41
# end processing batch 247
#
# start processing batch 248
#  size:41
# end processing batch 248
#
# start processing batch 249
#  size:41
# end processing batch 249
#
# start processing batch 250
#  size:41
# end processing batch 250
#
# start processing batch 251
#  size:41
# end processing batch 251
#
# start processing batch 252
#  size:41
# end processing batch 252
#
# start processing batch 253
#  size:41
# end processing batch 253
#
# start processing batch 254
#  size:41
# end processing batch 254
#
# start processing batch 255
#  size:41
# end processing batch 255
#
# start processing batch 256
#  size:41
# end processing batch 256
#
# start processing batch 257
#  size:41
# end processing batch 257
#
# start processing batch 258
#  size:41
# end processing batch 258
#
# start processing batch 259
#  size:41
# end processing batch 259
#
# start processing batch 260
#  size:41
# end processing batch 260
#
# start processing batch 261
#  size:41
# end processing batch 261
#
# start processing batch 262
#  size:41
# end processing batch 262
#
# start processing batch 263
#  size:41
# end processing batch 263
#
# start processing batch 264
#  size:41
# end processing batch 264
#
# start processing batch 265
#  size:41
# end processing batch 265
#
# start processing batch 266
#  size:41
# end processing batch 266
#
# start processing batch 267
#  size:41
# end processing batch 267
#
# start processing batch 268
#  size:41
# end processing batch 268
#
# start processing batch 269
#  size:41
# end processing batch 269
#
# start processing batch 270
#  size:41
# end processing batch 270
#
# start processing batch 271
#  size:41
# end processing batch 271
#
# start processing batch 272
#  size:41
# end processing batch 272
#
# start processing batch 273
#  size:41
# end processing batch 273
#
# start processing batch 274
#  size:41
# end processing batch 274
#
# start processing batch 275
#  size:41
# end processing batch 275
#
# start processing batch 276
#  size:41
# end processing batch 276
#
# start processing batch 277
#  size:41
# end processing batch 277
#
# start processing batch 278
#  size:41
# end processing batch 278
#
# start processing batch 279
#  size:41
# end processing batch 279
#
# start processing batch 280
#  size:41
# end processing batch 280
#
# start processing batch 281
#  size:41
# end processing batch 281
#
# start processing batch 282
#  size:41
# end processing batch 282
#
# start processing batch 283
#  size:41
# end processing batch 283
#
# start processing batch 284
#  size:41
# end processing batch 284
#
# start processing batch 285
#  size:41
# end processing batch 285
#
# start processing batch 286
#  size:41
# end processing batch 286
#
# start processing batch 287
#  size:41
# end processing batch 287
#
# start processing batch 288
#  size:41
# end processing batch 288
#
# start processing batch 289
#  size:41
# end processing batch 289
#
# start processing batch 290
#  size:41
# end processing batch 290
#
# start processing batch 291
#  size:41
# end processing batch 291
#
# start processing batch 292
#  size:41
# end processing batch 292
#
# start processing batch 293
#  size:41
# end processing batch 293
#
# start processing batch 294
#  size:41
# end processing batch 294
#
# start processing batch 295
#  size:41
# end processing batch 295
#
# start processing batch 296
#  size:41
# end processing batch 296
#
# start processing batch 297
#  size:41
# end processing batch 297
#
# start processing batch 298
#  size:41
# end processing batch 298
#
# start processing batch 299
#  size:41
# end processing batch 299
#
# start processing batch 300
#  size:41
# end processing batch 300
#
# start processing batch 301
#  size:41
# end processing batch 301
#
# start processing batch 302
#  size:41
# end processing batch 302
#
# start processing batch 303
#  size:41
# end processing batch 303
#
# start processing batch 304
#  size:41
# end processing batch 304
#
# start processing batch 305
#  size:41
# end processing batch 305
#
# start processing batch 306
#  size:41
# end processing batch 306
#
# start processing batch 307
#  size:41
# end processing batch 307
#
# start processing batch 308
#  size:41
# end processing batch 308
#
# start processing batch 309
#  size:41
# end processing batch 309
#
# start processing batch 310
#  size:41
# end processing batch 310
#
# start processing batch 311
#  size:41
# end processing batch 311
#
# start processing batch 312
#  size:41
# end processing batch 312
#
# start processing batch 313
#  size:41
# end processing batch 313
#
# start processing batch 314
#  size:41
# end processing batch 314
#
# start processing batch 315
#  size:41
# end processing batch 315
#
# start processing batch 316
#  size:41
# end processing batch 316
#
# start processing batch 317
#  size:41
# end processing batch 317
#
# start processing batch 318
#  size:41
# end processing batch 318
#
# start processing batch 319
#  size:41
# end processing batch 319
#
# start processing batch 320
#  size:41
# end processing batch 320
#
# start processing batch 321
#  size:41
# end processing batch 321
#
# start processing batch 322
#  size:41
# end processing batch 322
#
# start processing batch 323
#  size:41
# end processing batch 323
#
# start processing batch 324
#  size:41
# end processing batch 324
#
# start processing batch 325
#  size:41
# end processing batch 325
#
# start processing batch 326
#  size:41
# end processing batch 326
#
# start processing batch 327
#  size:41
# end processing batch 327
#
# start processing batch 328
#  size:41
# end processing batch 328
#
# start processing batch 329
#  size:41
# end processing batch 329
#
# start processing batch 330
#  size:41
# end processing batch 330
#
# start processing batch 331
#  size:41
# end processing batch 331
#
# start processing batch 332
#  size:41
# end processing batch 332
#
# start processing batch 333
#  size:41
# end processing batch 333
#
# start processing batch 334
#  size:41
# end processing batch 334
#
# start processing batch 335
#  size:41
# end processing batch 335
#
# start processing batch 336
#  size:41
# end processing batch 336
#
# start processing batch 337
#  size:41
# end processing batch 337
#
# start processing batch 338
#  size:41
# end processing batch 338
#
# start processing batch 339
#  size:41
# end processing batch 339
#
# start processing batch 340
#  size:41
# end processing batch 340
#
# start processing batch 341
#  size:41
# end processing batch 341
#
# start processing batch 342
#  size:41
# end processing batch 342
#
# start processing batch 343
#  size:41
# end processing batch 343
#
# start processing batch 344
#  size:41
# end processing batch 344
#
# start processing batch 345
#  size:41
# end processing batch 345
#
# start processing batch 346
#  size:41
# end processing batch 346
#
# start processing batch 347
#  size:41
# end processing batch 347
#
# start processing batch 348
#  size:41
# end processing batch 348
#
# start processing batch 349
#  size:41
# end processing batch 349
#
# start processing batch 350
#  size:41
# end processing batch 350
#
# start processing batch 351
#  size:41
# end processing batch 351
#
# start processing batch 352
#  size:41
# end processing batch 352
#
# start processing batch 353
#  size:41
# end processing batch 353
#
# start processing batch 354
#  size:41
# end processing batch 354
#
# start processing batch 355
#  size:41
# end processing batch 355
#
# start processing batch 356
#  size:41
# end processing batch 356
#
# start processing batch 357
#  size:41
# end processing batch 357
#
# start processing batch 358
#  size:41
# end processing batch 358
#
# start processing batch 359
#  size:41
# end processing batch 359
#
# start processing batch 360
#  size:41
# end processing batch 360
#
# start processing batch 361
#  size:41
# end processing batch 361
#
# start processing batch 362
#  size:41
# end processing batch 362
#
# start processing batch 363
#  size:41
# end processing batch 363
#
# start processing batch 364
#  size:41
# end processing batch 364
#
# start processing batch 365
#  size:41
# end processing batch 365
#
# start processing batch 366
#  size:41
# end processing batch 366
#
# start processing batch 367
#  size:41
# end processing batch 367
#
# start processing batch 368
#  size:41
# end processing batch 368
#
# start processing batch 369
#  size:41
# end processing batch 369
#
# start processing batch 370
#  size:41
# end processing batch 370
#
# start processing batch 371
#  size:41
# end processing batch 371
#
# start processing batch 372
#  size:41
# end processing batch 372
#
# start processing batch 373
#  size:41
# end processing batch 373
#
# start processing batch 374
#  size:41
# end processing batch 374
#
# start processing batch 375
#  size:41
# end processing batch 375
#
# start processing batch 376
#  size:41
# end processing batch 376
#
# start processing batch 377
#  size:41
# end processing batch 377
#
# start processing batch 378
#  size:41
# end processing batch 378
#
# start processing batch 379
#  size:41
# end processing batch 379
#
# start processing batch 380
#  size:41
# end processing batch 380
#
# start processing batch 381
#  size:41
# end processing batch 381
#
# start processing batch 382
#  size:41
# end processing batch 382
#
# start processing batch 383
#  size:41
# end processing batch 383
#
# start processing batch 384
#  size:41
# end processing batch 384
#
# start processing batch 385
#  size:41
# end processing batch 385
#
# start processing batch 386
#  size:41
# end processing batch 386
#
# start processing batch 387
#  size:41
# end processing batch 387
#
# start processing batch 388
#  size:41
# end processing batch 388
#
# start processing batch 389
#  size:41
# end processing batch 389
#
# start processing batch 390
#  size:41
# end processing batch 390
#
# start processing batch 391
#  size:41
# end processing batch 391
#
# start processing batch 392
#  size:41
# end processing batch 392
#
# start processing batch 393
#  size:41
# end processing batch 393
#
# start processing batch 394
#  size:41
# end processing batch 394
#
# start processing batch 395
#  size:41
# end processing batch 395
#
# start processing batch 396
#  size:41
# end processing batch 396
#
# start processing batch 397
#  size:41
# end processing batch 397
#
# start processing batch 398
#  size:41
# end processing batch 398
#
# start processing batch 399
#  size:41
# end processing batch 399
#
# start processing batch 400
#  size:41
# end processing batch 400
#
# start processing batch 401
#  size:41
# end processing batch 401
#
# start processing batch 402
#  size:41
# end processing batch 402
#
# start processing batch 403
#  size:41
# end processing batch 403
#
# start processing batch 404
#  size:41
# end processing batch 404
#
# start processing batch 405
#  size:41
# end processing batch 405
#
# start processing batch 406
#  size:41
# end processing batch 406
#
# start processing batch 407
#  size:41
# end processing batch 407
#
# start processing batch 408
#  size:41
# end processing batch 408
#
# start processing batch 409
#  size:41
# end processing batch 409
#
# start processing batch 410
#  size:41
# end processing batch 410
#
# start processing batch 411
#  size:41
# end processing batch 411
#
# start processing batch 412
#  size:41
# end processing batch 412
#
# start processing batch 413
#  size:41
# end processing batch 413
#
# start processing batch 414
#  size:41
# end processing batch 414
#
# start processing batch 415
#  size:41
# end processing batch 415
#
# start processing batch 416
#  size:41
# end processing batch 416
#
# start processing batch 417
#  size:41
# end processing batch 417
#
# start processing batch 418
#  size:41
# end processing batch 418
#
# start processing batch 419
#  size:41
# end processing batch 419
#
# start processing batch 420
#  size:41
# end processing batch 420
#
# start processing batch 421
#  size:41
# end processing batch 421
#
# start processing batch 422
#  size:41
# end processing batch 422
#
# start processing batch 423
#  size:41
# end processing batch 423
#
# start processing batch 424
#  size:41
# end processing batch 424
#
# start processing batch 425
#  size:41
# end processing batch 425
#
# start processing batch 426
#  size:41
# end processing batch 426
#
# start processing batch 427
#  size:41
# end processing batch 427
#
# start processing batch 428
#  size:41
# end processing batch 428
#
# start processing batch 429
#  size:41
# end processing batch 429
#
# start processing batch 430
#  size:41
# end processing batch 430
#
# start processing batch 431
#  size:41
# end processing batch 431
#
# start processing batch 432
#  size:41
# end processing batch 432
#
# start processing batch 433
#  size:41
# end processing batch 433
#
# start processing batch 434
#  size:41
# end processing batch 434
#
# start processing batch 435
#  size:41
# end processing batch 435
#
# start processing batch 436
#  size:41
# end processing batch 436
#
# start processing batch 437
#  size:41
# end processing batch 437
#
# start processing batch 438
#  size:41
# end processing batch 438
#
# start processing batch 439
#  size:41
# end processing batch 439
#
# start processing batch 440
#  size:41
# end processing batch 440
#
# start processing batch 441
#  size:41
# end processing batch 441
#
# start processing batch 442
#  size:41
# end processing batch 442
#
# start processing batch 443
#  size:41
# end processing batch 443
#
# start processing batch 444
#  size:41
# end processing batch 444
#
# start processing batch 445
#  size:41
# end processing batch 445
#
# start processing batch 446
#  size:41
# end processing batch 446
#
# start processing batch 447
#  size:41
# end processing batch 447
#
# start processing batch 448
#  size:41
# end processing batch 448
#
# start processing batch 449
#  size:41
# end processing batch 449
#
# start processing batch 450
#  size:41
# end processing batch 450
#
# start processing batch 451
#  size:41
# end processing batch 451
#
# start processing batch 452
#  size:41
# end processing batch 452
#
# start processing batch 453
#  size:41
# end processing batch 453
#
# start processing batch 454
#  size:41
# end processing batch 454
#
# start processing batch 455
#  size:41
# end processing batch 455
#
# start processing batch 456
#  size:41
# end processing batch 456
#
# start processing batch 457
#  size:41
# end processing batch 457
#
# start processing batch 458
#  size:41
# end processing batch 458
#
# start processing batch 459
#  size:41
# end processing batch 459
#
# start processing batch 460
#  size:41
# end processing batch 460
#
# start processing batch 461
#  size:41
# end processing batch 461
#
# start processing batch 462
#  size:41
# end processing batch 462
#
# start processing batch 463
#  size:41
# end processing batch 463
#
# start processing batch 464
#  size:41
# end processing batch 464
#
# start processing batch 465
#  size:41
# end processing batch 465
#
# start processing batch 466
#  size:41
# end processing batch 466
#
# start processing batch 467
#  size:41
# end processing batch 467
#
# start processing batch 468
#  size:41
# end processing batch 468
#
# start processing batch 469
#  size:41
# end processing batch 469
#
# start processing batch 470
#  size:41
# end processing batch 470
#
# start processing batch 471
#  size:41
# end processing batch 471
#
# start processing batch 472
#  size:41
# end processing batch 472
#
# start processing batch 473
#  size:41
# end processing batch 473
#
# start processing batch 474
#  size:41
# end processing batch 474
#
# start processing batch 475
#  size:41
# end processing batch 475
#
# start processing batch 476
#  size:41
# end processing batch 476
#
# start processing batch 477
#  size:41
# end processing batch 477
#
# start processing batch 478
#  size:41
# end processing batch 478
#
# start processing batch 479
#  size:41
# end processing batch 479
#
# start processing batch 480
#  size:41
# end processing batch 480
#
# start processing batch 481
#  size:41
# end processing batch 481
#
# start processing batch 482
#  size:41
# end processing batch 482
#
# start processing batch 483
#  size:41
# end processing batch 483
#
# start processing batch 484
#  size:41
# end processing batch 484
#
# start processing batch 485
#  size:41
# end processing batch 485
#
# start processing batch 486
#  size:41
# end processing batch 486
#
# start processing batch 487
#  size:41
# end processing batch 487
#
# start processing batch 488
#  size:41
# end processing batch 488
#
# start processing batch 489
#  size:41
# end processing batch 489
#
# start processing batch 490
#  size:41
# end processing batch 490
#
# start processing batch 491
#  size:41
# end processing batch 491
#
# start processing batch 492
#  size:41
# end processing batch 492
#
# start processing batch 493
#  size:41
# end processing batch 493
#
# start processing batch 494
#  size:41
# end processing batch 494
#
# start processing batch 495
#  size:41
# end processing batch 495
#
# start processing batch 496
#  size:41
# end processing batch 496
#
# start processing batch 497
#  size:41
# end processing batch 497
#
# start processing batch 498
#  size:41
# end processing batch 498
#
# start processing batch 499
#  size:41
# end processing batch 499
#
# start processing batch 500
#  size:41
# end processing batch 500

# %% [markdown]
# In this section, the gathering of artists info information is performed

# %%
for index, artist in data.iterrows():
    info=search_for_artist(token,artist['Artist'])
    data.at[index,'Followers']=info['followers']['total']
    data.at[index,'Genres']=info['genres']
    data.at[index,'Popularity']=info['popularity']
# Out:
# Gorillaz
# Red Hot Chili Peppers
# 50 Cent
# Metallica
# Coldplay
# Daft Punk
# Linkin Park
# Radiohead
# AC/DC
# Black Eyed Peas
# Michael Jackson
# P!nk
# Eminem
# Pharrell Williams
# Khalid
# Shakira
# Machine Gun Kelly
# Nicky Jam
# The Beatles
# Pitbull
# Sean Paul
# Elvis Presley
# 2Pac
# Snoop Dogg
# Lil Wayne
# Sia
# Fleetwood Mac
# ABBA
# Frank Sinatra
# Tiësto
# Elton John
# JAY-Z
# 21 Savage
# Kanye West
# Luis Miguel
# Beyoncé
# Daddy Yankee
# Don Toliver
# Camilo
# Britney Spears
# Farruko
# Wisin & Yandel
# Disney
# Chris Brown
# Tory Lanez
# Mariah Carey
# A.R. Rahman
# Luis R Conriquez
# The Kid LAROI
# Lil Nas X
# Maria Becerra
# MC Ryan SP
# Natanael Cano
# JVKE
# Lil Tjay
# Summer Walker
# Baby Keem
# Giveon
# Tiago PZK
# Geolier
# Lil Tecca
# Polimá Westcoast
# Kevin Kaarl
# Lofi Fruits Music
# Chill Fruits Music
# girl in red
# (G)I-DLE
# Tems
# Connor Price
# Ke Personajes
# Edgardo Nuñez
# iann dior
# Grupo Menos É Mais
# Dallass
# Apache 207
# 24kGoldn
# Kenia OS
# Mc Poze do Rodo
# ATEEZ
# Coi Leray
# Callejero Fino
# Ajaxx
# j-hope
# Los Dos Carnales
# Teto
# Marcianeke
# Zack Tabudlo
# Junior H
# Zach Bryan
# Pop Smoke
# Peso Pluma
# Cris Mj
# Nicki Nicole
# TOMORROW X TOGETHER
# Guilherme & Benuto
# Fred again..
# AP Dhillon
# Eslabon Armado
# Øneheart
# Kotim
# YOASOBI
# Blessd
# Ado
# Tiakola
# ITZY
# sped up nightcore
# Morad
# UZI
# Gazo
# Vaundy
# Felipe Amorim
# NATTAN
# Gurinder Gill
# Solfeggio Healing Frequencies MT
# Kato
# Lvbel C5
# CoComelon
# Quevedo
# Stephen Sanchez
# Mc Paiva ZS
# MEDUZA
# Standly
# Pailita
# Mainstreet
# Miracle Tones
# Ivan Cornejo
# Fujii Kaze
# Hotel Ugly
# ENHYPEN
# Oscar Maydon
# DVRST
# Nicky Youre
# Tz da Coronel
# d4vd
# Ana Castela
# Kordhell
# Mari Fernandez
# Rosa Linn
# PinkPantheress
# BoyWithUke
# FIFA Sound
# Eden Muñoz
# INTERWORLD
# Silk Sonic
# Rain Fruits Sounds
# João Gomes
# Oruam
# Shubh
# Bailey Zimmerman
# IVE
# Arcane
# Sleepy Penguin
# Stars Music Chile
# AYLIVA
# NewJeans
# Grupo Frontera
# Jung Kook
# LE SSERAFIM
# ThxSoMch
# SICK LEGEND

# %% [markdown]
# Here are specified where the output files are saved

# %%
data.reset_index(drop=True, inplace=True)
print(data)
data.to_csv('../data/Artist_info.csv',index=False,encoding='utf-8')
album.drop_duplicates()
album.to_csv('../data/Album_info.csv',index=False,encoding='utf-8')
# Out:
#                      Artist  Followers  \
# 0                  Gorillaz   11029273
# 1     Red Hot Chili Peppers   20336411
# 2                   50 Cent   12956918
# 3                 Metallica   26352973
# 4                  Coldplay   48226976
# ...                     ...        ...
# 2074         Grupo Frontera    2355149
# 2075              Jung Kook   11298008
# 2076            LE SSERAFIM    3536979
# 2077               ThxSoMch     308065
# 2078            SICK LEGEND     179969
#
#                                                  Genres  Popularity
# 0              [alternative hip hop, modern rock, rock]          76
# 1     [alternative rock, funk metal, funk rock, perm...          81
# 2     [east coast hip hop, gangster rap, hip hop, po...          80
# 3     [hard rock, metal, old school thrash, rock, th...          79
# 4                                 [permanent wave, pop]          85
# ...                                                 ...         ...
# 2074                              [musica chihuahuense]          83
# 2075                                            [k-pop]          89
# 2076                                 [k-pop girl group]          76
# 2077                                      [bedroom r&b]          66
# 2078                                    [gym hardstyle]          66
#
# [2079 rows x 4 columns]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/gianluca/Documents/Universita/DB2/spotify_api/spotify.ipynb Cell 18 line 4
#       <a href='vscode-notebook-cell:/Users/gianluca/Documents/Universita/DB2/spotify_api/spotify.ipynb#X23sZmlsZQ%3D%3D?line=1'>2</a> print(data)
#       <a href='vscode-notebook-cell:/Users/gianluca/Documents/Universita/DB2/spotify_api/spotify.ipynb#X23sZmlsZQ%3D%3D?line=2'>3</a> data.to_csv('../data/Artist_info.csv',index=False,encoding='utf-8')
# ----> <a href='vscode-notebook-cell:/Users/gianluca/Documents/Universita/DB2/spotify_api/spotify.ipynb#X23sZmlsZQ%3D%3D?line=3'>4</a> album.drop_duplicates()
#       <a href='vscode-notebook-cell:/Users/gianluca/Documents/Universita/DB2/spotify_api/spotify.ipynb#X23sZmlsZQ%3D%3D?line=4'>5</a> album.to_csv('../data/Album_info.csv',index=False,encoding='utf-8')
#       <a href='vscode-notebook-cell:/Users/gianluca/Documents/Universita/DB2/spotify_api/spotify.ipynb#X23sZmlsZQ%3D%3D?line=7'>8</a> print(album)
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/frame.py:6672, in DataFrame.drop_duplicates(self, subset, keep, inplace, ignore_index)
#    6670 inplace = validate_bool_kwarg(inplace, "inplace")
#    6671 ignore_index = validate_bool_kwarg(ignore_index, "ignore_index")
# -> 6672 duplicated = self.duplicated(subset, keep=keep)
#    6674 result = self[-duplicated]
#    6675 if ignore_index:
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/frame.py:6814, in DataFrame.duplicated(self, subset, keep)
#    6812 else:
#    6813     vals = (col.values for name, col in self.items() if name in subset)
# -> 6814     labels, shape = map(list, zip(*map(f, vals)))
#    6816     ids = get_group_index(
#    6817         labels,
#    6818         # error: Argument 1 to "tuple" has incompatible type "List[_T]";
#    (...)
#    6822         xnull=False,
#    6823     )
#    6824     result = self._constructor_sliced(duplicated(ids, keep), index=self.index)
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/frame.py:6782, in DataFrame.duplicated.<locals>.f(vals)
#    6781 def f(vals) -> tuple[np.ndarray, int]:
# -> 6782     labels, shape = algorithms.factorize(vals, size_hint=len(self))
#    6783     return labels.astype("i8", copy=False), len(shape)
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/algorithms.py:822, in factorize(values, sort, na_sentinel, use_na_sentinel, size_hint)
#     819             # Don't modify (potentially user-provided) array
#     820             values = np.where(null_mask, na_value, values)
# --> 822     codes, uniques = factorize_array(
#     823         values,
#     824         na_sentinel=na_sentinel_arg,
#     825         size_hint=size_hint,
#     826     )
#     828 if sort and len(uniques) > 0:
#     829     if na_sentinel is None:
#     830         # TODO: Can remove when na_sentinel=na_sentinel as in TODO above
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/algorithms.py:578, in factorize_array(values, na_sentinel, size_hint, na_value, mask)
#     575 hash_klass, values = _get_hashtable_algo(values)
#     577 table = hash_klass(size_hint or len(values))
# --> 578 uniques, codes = table.factorize(
#     579     values,
#     580     na_sentinel=na_sentinel,
#     581     na_value=na_value,
#     582     mask=mask,
#     583     ignore_na=ignore_na,
#     584 )
#     586 # re-cast e.g. i8->dt64/td64, uint8->bool
#     587 uniques = _reconstruct_data(uniques, original.dtype, original)
#
# File pandas/_libs/hashtable_class_helper.pxi:5943, in pandas._libs.hashtable.PyObjectHashTable.factorize()
#
# File pandas/_libs/hashtable_class_helper.pxi:5857, in pandas._libs.hashtable.PyObjectHashTable._unique()
#
# TypeError: unhashable type: 'list'
